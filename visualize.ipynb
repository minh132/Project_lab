# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
img = np.load("/home/admin_mcn/thaotlp/data/ISIC/output/ISIC_0000002.npy")[0][0]

# %%
plt.imshow(img)
